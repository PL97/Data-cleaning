# %%
import numpy as np
import pandas as pd
import SimilarDection as SD
import matplotlib.pyplot as plt

# %%
fname = 'full_name.csv'
data = pd.read_csv(fname, index_col = 0)
print(data.head())
# Out:
#                 0                 1
# 0     Abig. SMITH     Abigail SMITH
# 1     Abig. JONES     Abigail JONES
# 2     Abig. BROWN     Abigail BROWN
# 3   Abig. JOHNSON   Abigail JOHNSON
# 4  Abig. WILLIAMS  Abigail WILLIAMS

# %%
test = SD.SimilarDection(2, 1, 0.5, 0.3)
score = []
for row in data.itertuples(index=False):
    score.append(test.Smith_Waterman(row[0], row[1])[2])

# %%
new_score = list(map(lambda x: int(x * 100), score))
round_score = []
for s in new_score:
    if s<0:
        temp = 0
    elif s%10 < 3:
        temp = int(s/10)*10
    elif s%10 <7:
        temp = int(s/10)*10 + 5
    else:
        temp = (int(s/10) + 1)*10
    round_score.append(temp)

# %%
hist_score = pd.DataFrame(round_score)
hist_score[hist_score.columns[0]].value_counts().plot.bar()
plt.show()

# %%
idx = np.where(hist_score<60)[0]
name1_l = data.iloc[:, 0]
name2_l = data.iloc[:, 1]
name1 = list(name1_l[idx])
name2 = list(name2_l[idx])
false_positive = list(zip(name1, name2))
tmp = [x for x in false_positive if not('Alf.' in x[0] or 'Dy' in x[0])]
# print(len(false_positive))
# print(name2[1])
rate = float(len(false_positive))/len(data)
print(rate)
print(false_positive)
# Out:
# 0.17163865546218487
# [('Alex. HALL', 'Alexander HALL'), ('Alex. HILL', 'Alexander HILL'), ('Alex. WOOD', 'Alexander WOOD'), ('Alex. KING', 'Alexander KING'), ('Alex. JOHN', 'Alexander JOHN'), ('Alex. LEE', 'Alexander LEE'), ('Alex. COOK', 'Alexander COOK'), ('Alex. MC', 'Alexander MC'), ('Alex. BELL', 'Alexander BELL'), ('Alex. WARD', 'Alexander WARD'), ('Alex. GRAY', 'Alexander GRAY'), ('Alex. SHAW', 'Alexander SHAW'), ('Alex. REED', 'Alexander REED'), ('Alex. MAY', 'Alexander MAY'), ('Alex. COX', 'Alexander COX'), ('Alex. MISS', 'Alexander MISS'), ('Alex. HUNT', 'Alexander HUNT'), ('Alex. ROSS', 'Alexander ROSS'), ('Alex. WEST', 'Alexander WEST'), ('Alex. HART', 'Alexander HART'), ('Alex. FORD', 'Alexander FORD'), ('Alex. CO', 'Alexander CO'), ('Alex. COLE', 'Alexander COLE'), ('Alex. FOX', 'Alexander FOX'), ('Alex. DAY', 'Alexander DAY'), ('Alex. LONG', 'Alexander LONG'), ('Alex. WEBB', 'Alexander WEBB'), ('Alex. WM', 'Alexander WM'), ('Alex. LANE', 'Alexander LANE'), ('Alex. CITY', 'Alexander CITY'), ('Alex. RICE', 'Alexander RICE'), ('Alex. DUNN', 'Alexander DUNN'), ('Alex. REID', 'Alexander REID'), ('Alex. MARY', 'Alexander MARY'), ('Alex. PAGE', 'Alexander PAGE'), ('Alex. ROSE', 'Alexander ROSE'), ('Alex. ANN', 'Alexander ANN'), ('Alf. SMITH', 'Alphonse SMITH'), ('Alf. JONES', 'Alphonse JONES'), ('Alf. BROWN', 'Alphonse BROWN'), ('Alf. JOHNSON', 'Alphonse JOHNSON'), ('Alf. WILLIAMS', 'Alphonse WILLIAMS'), ('Alf. MILLER', 'Alphonse MILLER'), ('Alf. TAYLOR', 'Alphonse TAYLOR'), ('Alf. WILSON', 'Alphonse WILSON'), ('Alf. DAVIS', 'Alphonse DAVIS'), ('Alf. WHITE', 'Alphonse WHITE'), ('Alf. CLARK', 'Alphonse CLARK'), ('Alf. HALL', 'Alphonse HALL'), ('Alf. THOMAS', 'Alphonse THOMAS'), ('Alf. THOMPSON', 'Alphonse THOMPSON'), ('Alf. MOORE', 'Alphonse MOORE'), ('Alf. HILL', 'Alphonse HILL'), ('Alf. WALKER', 'Alphonse WALKER'), ('Alf. ANDERSON', 'Alphonse ANDERSON'), ('Alf. WRIGHT', 'Alphonse WRIGHT'), ('Alf. MARTIN', 'Alphonse MARTIN'), ('Alf. WOOD', 'Alphonse WOOD'), ('Alf. ALLEN', 'Alphonse ALLEN'), ('Alf. ROBINSON', 'Alphonse ROBINSON'), ('Alf. LEWIS', 'Alphonse LEWIS'), ('Alf. SCOTT', 'Alphonse SCOTT'), ('Alf. YOUNG', 'Alphonse YOUNG'), ('Alf. JACKSON', 'Alphonse JACKSON'), ('Alf. ADAMS', 'Alphonse ADAMS'), ('Alf. TRYNISKI', 'Alphonse TRYNISKI'), ('Alf. GREEN', 'Alphonse GREEN'), ('Alf. EVANS', 'Alphonse EVANS'), ('Alf. KING', 'Alphonse KING'), ('Alf. BAKER', 'Alphonse BAKER'), ('Alf. JOHN', 'Alphonse JOHN'), ('Alf. HARRIS', 'Alphonse HARRIS'), ('Alf. ROBERTS', 'Alphonse ROBERTS'), ('Alf. CAMPBELL', 'Alphonse CAMPBELL'), ('Alf. JAMES', 'Alphonse JAMES'), ('Alf. STEWART', 'Alphonse STEWART'), ('Alf. LEE', 'Alphonse LEE'), ('Alf. COUNTY', 'Alphonse COUNTY'), ('Alf. TURNER', 'Alphonse TURNER'), ('Alf. PARKER', 'Alphonse PARKER'), ('Alf. COOK', 'Alphonse COOK'), ('Alf. MC', 'Alphonse MC'), ('Alf. EDWARDS', 'Alphonse EDWARDS'), ('Alf. MORRIS', 'Alphonse MORRIS'), ('Alf. MITCHELL', 'Alphonse MITCHELL'), ('Alf. BELL', 'Alphonse BELL'), ('Alf. WARD', 'Alphonse WARD'), ('Alf. WATSON', 'Alphonse WATSON'), ('Alf. MORGAN', 'Alphonse MORGAN'), ('Alf. DAVIES', 'Alphonse DAVIES'), ('Alf. COOPER', 'Alphonse COOPER'), ('Alf. PHILLIPS', 'Alphonse PHILLIPS'), ('Alf. ROGERS', 'Alphonse ROGERS'), ('Alf. GRAY', 'Alphonse GRAY'), ('Alf. HUGHES', 'Alphonse HUGHES'), ('Alf. HARRISON', 'Alphonse HARRISON'), ('Alf. CARTER', 'Alphonse CARTER'), ('Alf. MURPHY', 'Alphonse MURPHY'), ('Alf. COLLINS', 'Alphonse COLLINS'), ('Alf. HENRY', 'Alphonse HENRY'), ('Alf. FOSTER', 'Alphonse FOSTER'), ('Alf. RICHARDSON', 'Alphonse RICHARDSON'), ('Alf. RUSSELL', 'Alphonse RUSSELL'), ('Alf. HAMILTON', 'Alphonse HAMILTON'), ('Alf. SHAW', 'Alphonse SHAW'), ('Alf. BENNETT', 'Alphonse BENNETT'), ('Alf. HOWARD', 'Alphonse HOWARD'), ('Alf. REED', 'Alphonse REED'), ('Alf. FISHER', 'Alphonse FISHER'), ('Alf. MARSHALL', 'Alphonse MARSHALL'), ('Alf. MAY', 'Alphonse MAY'), ('Alf. CHURCH', 'Alphonse CHURCH'), ('Alf. WASHINGTON', 'Alphonse WASHINGTON'), ('Alf. KELLY', 'Alphonse KELLY'), ('Alf. PRICE', 'A ...

# %%
name1_l = data.iloc[:, 0]
name2_l = data.iloc[:, 1]
t = np.random.permutation(name2_l)
false_data = zip(name1_l, t)
false_score = []
test = SD.SimilarDection(2, 1, 0.5, 0.3)
for str1, str2 in false_data:
#     print(str1, '----',  str2)
#     print(str1, str2)
    false_score.append(test.Smith_Waterman(str1, str2)[2])

# %%
round_false_score = []
new_false_score = list(map(lambda x: int(x * 100), false_score))
for s in new_false_score:
    if s<0:
        temp = 0
    elif s%10 < 3:
        temp = int(s/10)*10
    elif s%10 <7:
        temp = int(s/10)*10 + 5
    else:
        temp = (int(s/10) + 1)*10
    round_false_score.append(temp)

hist_false_score = pd.DataFrame(round_false_score)
hist_false_score[hist_score.columns[0]].value_counts().plot.bar()
plt.show()

# %%
idx = np.where(hist_false_score > 60)[0]
name1 = list(name1_l[idx])
name2 = list(t[idx])
false_positive = list(zip(name1, name2))
print(false_positive)
# Out:
# [('Alex.r JOHNSTON', 'Alexander JOHNSTON'), ('Jas THOMPSON', 'Ursula THOMPSON')]

# %%
str1 = 'Jas THOMPSON'
str2 = 'Ursula THOMPSON'
test = SD.SimilarDection(2, 1, 0.5, 0.3)
result = test.Smith_Waterman(str1, str2)
print(result)
# Out:
# ('/br/__ HUGHES', '/br/el HUGHES', 0.5760000000000001)
